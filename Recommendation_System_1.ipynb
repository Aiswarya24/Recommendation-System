# %%
# !pip install -qq convokit
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.2/183.2 kB 4.2 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 16.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.5/235.5 kB 24.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 677.1/677.1 kB 33.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 300.4/300.4 kB 20.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.4/175.4 kB 23.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 kB 8.5 MB/s eta 0:00:00
#   Building wheel for convokit (pyproject.toml) ... done
#   Building wheel for emoji (setup.py) ... done

# %%
# !pip install -qq scikit-surprise
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 772.0/772.0 kB 10.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Building wheel for scikit-surprise (setup.py) ... done

# %%
import pandas as pd
import numpy as np
from surprise import Dataset, Reader, SVD
from surprise.model_selection import train_test_split
from surprise import accuracy
import convokit

# %%
# Load the Cornell Movie Dialogs Corpus
corpus = convokit.Corpus(filename=convokit.download("movie-corpus"))
# Out:
# Downloading movie-corpus to /root/.convokit/downloads/movie-corpus
# Downloading movie-corpus from http://zissou.infosci.cornell.edu/convokit/datasets/movie-corpus/movie-corpus.zip (40.9MB)... Done
# No configuration file found at /root/.convokit/config.yml; writing with contents:
# # Default Backend Parameters
# db_host: localhost:27017
# data_directory: ~/.convokit/saved-corpora
# default_backend: mem

# %%
# Display basic statistics
print("Number of conversations:", len(corpus.conversations))
print("Number of users:", len(corpus.speakers))
print("Number of utterances:", len(corpus.utterances))
# Out:
# Number of conversations: 83097
# Number of users: 9035
# Number of utterances: 304713

# %%
# Display information about conversations
for convo_id in corpus.get_conversation_ids():
    convo = corpus.get_conversation(convo_id)
    print("Conversation ID:", convo_id)
    print("Metadata:", convo.meta)
    print("Number of utterances in conversation:", len(convo.get_utterance_ids()))
    print()
# Out:
# Streaming output truncated to the last 5000 lines.
#
# Conversation ID: L235550
# Metadata: ConvoKitMeta({'movie_idx': 'm71', 'movie_name': 'ghost ship', 'release_year': '2002', 'rating': '5.30', 'votes': '26413', 'genre': "['horror', 'mystery', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L235592
# Metadata: ConvoKitMeta({'movie_idx': 'm71', 'movie_name': 'ghost ship', 'release_year': '2002', 'rating': '5.30', 'votes': '26413', 'genre': "['horror', 'mystery', 'thriller']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L235589
# Metadata: ConvoKitMeta({'movie_idx': 'm71', 'movie_name': 'ghost ship', 'release_year': '2002', 'rating': '5.30', 'votes': '26413', 'genre': "['horror', 'mystery', 'thriller']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L235587
# Metadata: ConvoKitMeta({'movie_idx': 'm71', 'movie_name': 'ghost ship', 'release_year': '2002', 'rating': '5.30', 'votes': '26413', 'genre': "['horror', 'mystery', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L235566
# Metadata: ConvoKitMeta({'movie_idx': 'm71', 'movie_name': 'ghost ship', 'release_year': '2002', 'rating': '5.30', 'votes': '26413', 'genre': "['horror', 'mystery', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L235557
# Metadata: ConvoKitMeta({'movie_idx': 'm71', 'movie_name': 'ghost ship', 'release_year': '2002', 'rating': '5.30', 'votes': '26413', 'genre': "['horror', 'mystery', 'thriller']"})
# Number of utterances in conversation: 9
#
# Conversation ID: L237482
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L237472
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 10
#
# Conversation ID: L237360
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L237357
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L237293
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 6
#
# Conversation ID: L237152
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L236914
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 12
#
# Conversation ID: L236909
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L236665
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L237450
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L237446
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L237442
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L237283
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L237206
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L237204
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L237196
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 7
#
# Conversation ID: L237194
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L237366
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 11
#
# Conversation ID: L237165
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 8
#
# Conversation ID: L237160
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L237037
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 8
#
# Conversation ID: L236951
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L236747
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L237070
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 6
#
# Conversation ID: L237060
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 6
#
# Conversation ID: L237056
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L237564
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L237253
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 10
#
# Conversation ID: L237251
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L237236
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 14
#
# Conversation ID: L237231
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L237229
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L236843
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L236576
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L236570
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L236551
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L236546
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L236535
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L236526
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L236520
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L236516
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L236504
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L237562
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L237559
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L237555
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L237501
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 6
#
# Conversation ID: L237498
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L237465
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 7
#
# Conversation ID: L237463
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L237353
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L237345
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 8
#
# Conversation ID: L237335
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 10
#
# Conversation ID: L237218
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 11
#
# Conversation ID: L237181
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 13
#
# Conversation ID: L237173
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 8
#
# Conversation ID: L237107
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L237103
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L237088
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L237081
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L237078
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L237046
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 10
#
# Conversation ID: L236944
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 7
#
# Conversation ID: L236926
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 8
#
# Conversation ID: L236895
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 12
#
# Conversation ID: L236890
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L236879
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 8
#
# Conversation ID: L236796
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L236783
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L236771
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 7
#
# Conversation ID: L236767
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L236764
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L236762
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L236718
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L236699
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L236694
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L236690
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L236679
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L236676
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L236672
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L236669
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L236659
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 6
#
# Conversation ID: L236657
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L236654
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L236636
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 10
#
# Conversation ID: L236634
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L236599
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L236597
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L236593
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L236587
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L236582
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L236574
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L236572
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L236565
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L236560
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L236557
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L236555
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L236549
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L236543
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L236539
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L236533
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L236530
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L236496
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 6
#
# Conversation ID: L236492
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L236487
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L236474
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L236472
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L236469
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L236463
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L236460
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L236451
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L236444
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L236441
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L236438
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L236432
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L236428
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L236426
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L236421
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L236418
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L236416
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L236410
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L236396
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 6
#
# Conversation ID: L236392
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L236389
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L236386
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L236368
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L236355
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 6
#
# Conversation ID: L236353
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L236347
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 6
#
# Conversation ID: L236343
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L236382
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L236377
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L236373
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L236646
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L236361
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 7
#
# Conversation ID: L237456
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L237155
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L237313
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L236730
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L236612
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L236610
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L236605
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L236716
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L236713
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L236706
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 7
#
# Conversation ID: L236684
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 6
#
# Conversation ID: L236413
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L236406
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L236402
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L237092
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 8
#
# Conversation ID: L237461
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L237429
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 11
#
# Conversation ID: L237412
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 17
#
# Conversation ID: L237395
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 17
#
# Conversation ID: L237392
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L237390
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L237388
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L237386
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L237378
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 8
#
# Conversation ID: L237315
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 20
#
# Conversation ID: L237305
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 8
#
# Conversation ID: L237275
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 8
#
# Conversation ID: L237266
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 9
#
# Conversation ID: L237264
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L237209
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 9
#
# Conversation ID: L237142
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 7
#
# Conversation ID: L237138
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L237136
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L237118
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 18
#
# Conversation ID: L237115
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L237112
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L237024
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 7
#
# Conversation ID: L237015
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 9
#
# Conversation ID: L237006
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 6
#
# Conversation ID: L237003
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L237000
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L236988
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 12
#
# Conversation ID: L236978
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L236974
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L236970
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L236968
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L236873
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L236867
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L236862
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L236854
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 8
#
# Conversation ID: L236850
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L236838
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L236830
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 6
#
# Conversation ID: L236826
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L236814
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 12
#
# Conversation ID: L236808
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 6
#
# Conversation ID: L236802
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 6
#
# Conversation ID: L236736
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L236722
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 8
#
# Conversation ID: L236629
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L236627
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L236625
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L236622
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L236620
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L236616
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L236785
# Metadata: ConvoKitMeta({'movie_idx': 'm72', 'movie_name': 'ghost world', 'release_year': '2001', 'rating': '7.70', 'votes': '43550', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 6
#
# Conversation ID: L237491
# ...
# Number of utterances in conversation: 2
#
# Conversation ID: L650491
# Metadata: ConvoKitMeta({'movie_idx': 'm604', 'movie_name': 'white angel', 'release_year': '1994', 'rating': '4.40', 'votes': '99', 'genre': "['drama', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L650483
# Metadata: ConvoKitMeta({'movie_idx': 'm604', 'movie_name': 'white angel', 'release_year': '1994', 'rating': '4.40', 'votes': '99', 'genre': "['drama', 'thriller']"})
# Number of utterances in conversation: 8
#
# Conversation ID: L650469
# Metadata: ConvoKitMeta({'movie_idx': 'm604', 'movie_name': 'white angel', 'release_year': '1994', 'rating': '4.40', 'votes': '99', 'genre': "['drama', 'thriller']"})
# Number of utterances in conversation: 14
#
# Conversation ID: L650466
# Metadata: ConvoKitMeta({'movie_idx': 'm604', 'movie_name': 'white angel', 'release_year': '1994', 'rating': '4.40', 'votes': '99', 'genre': "['drama', 'thriller']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L650456
# Metadata: ConvoKitMeta({'movie_idx': 'm604', 'movie_name': 'white angel', 'release_year': '1994', 'rating': '4.40', 'votes': '99', 'genre': "['drama', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L650435
# Metadata: ConvoKitMeta({'movie_idx': 'm604', 'movie_name': 'white angel', 'release_year': '1994', 'rating': '4.40', 'votes': '99', 'genre': "['drama', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L650333
# Metadata: ConvoKitMeta({'movie_idx': 'm604', 'movie_name': 'white angel', 'release_year': '1994', 'rating': '4.40', 'votes': '99', 'genre': "['drama', 'thriller']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L650329
# Metadata: ConvoKitMeta({'movie_idx': 'm604', 'movie_name': 'white angel', 'release_year': '1994', 'rating': '4.40', 'votes': '99', 'genre': "['drama', 'thriller']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L650325
# Metadata: ConvoKitMeta({'movie_idx': 'm604', 'movie_name': 'white angel', 'release_year': '1994', 'rating': '4.40', 'votes': '99', 'genre': "['drama', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L650321
# Metadata: ConvoKitMeta({'movie_idx': 'm604', 'movie_name': 'white angel', 'release_year': '1994', 'rating': '4.40', 'votes': '99', 'genre': "['drama', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L650315
# Metadata: ConvoKitMeta({'movie_idx': 'm604', 'movie_name': 'white angel', 'release_year': '1994', 'rating': '4.40', 'votes': '99', 'genre': "['drama', 'thriller']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L650293
# Metadata: ConvoKitMeta({'movie_idx': 'm604', 'movie_name': 'white angel', 'release_year': '1994', 'rating': '4.40', 'votes': '99', 'genre': "['drama', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L650753
# Metadata: ConvoKitMeta({'movie_idx': 'm604', 'movie_name': 'white angel', 'release_year': '1994', 'rating': '4.40', 'votes': '99', 'genre': "['drama', 'thriller']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L650448
# Metadata: ConvoKitMeta({'movie_idx': 'm604', 'movie_name': 'white angel', 'release_year': '1994', 'rating': '4.40', 'votes': '99', 'genre': "['drama', 'thriller']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L650444
# Metadata: ConvoKitMeta({'movie_idx': 'm604', 'movie_name': 'white angel', 'release_year': '1994', 'rating': '4.40', 'votes': '99', 'genre': "['drama', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L650440
# Metadata: ConvoKitMeta({'movie_idx': 'm604', 'movie_name': 'white angel', 'release_year': '1994', 'rating': '4.40', 'votes': '99', 'genre': "['drama', 'thriller']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L650300
# Metadata: ConvoKitMeta({'movie_idx': 'm604', 'movie_name': 'white angel', 'release_year': '1994', 'rating': '4.40', 'votes': '99', 'genre': "['drama', 'thriller']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L650285
# Metadata: ConvoKitMeta({'movie_idx': 'm604', 'movie_name': 'white angel', 'release_year': '1994', 'rating': '4.40', 'votes': '99', 'genre': "['drama', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L650684
# Metadata: ConvoKitMeta({'movie_idx': 'm604', 'movie_name': 'white angel', 'release_year': '1994', 'rating': '4.40', 'votes': '99', 'genre': "['drama', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L650381
# Metadata: ConvoKitMeta({'movie_idx': 'm604', 'movie_name': 'white angel', 'release_year': '1994', 'rating': '4.40', 'votes': '99', 'genre': "['drama', 'thriller']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L650378
# Metadata: ConvoKitMeta({'movie_idx': 'm604', 'movie_name': 'white angel', 'release_year': '1994', 'rating': '4.40', 'votes': '99', 'genre': "['drama', 'thriller']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L650373
# Metadata: ConvoKitMeta({'movie_idx': 'm604', 'movie_name': 'white angel', 'release_year': '1994', 'rating': '4.40', 'votes': '99', 'genre': "['drama', 'thriller']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L650578
# Metadata: ConvoKitMeta({'movie_idx': 'm604', 'movie_name': 'white angel', 'release_year': '1994', 'rating': '4.40', 'votes': '99', 'genre': "['drama', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L650575
# Metadata: ConvoKitMeta({'movie_idx': 'm604', 'movie_name': 'white angel', 'release_year': '1994', 'rating': '4.40', 'votes': '99', 'genre': "['drama', 'thriller']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L650570
# Metadata: ConvoKitMeta({'movie_idx': 'm604', 'movie_name': 'white angel', 'release_year': '1994', 'rating': '4.40', 'votes': '99', 'genre': "['drama', 'thriller']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L650323
# Metadata: ConvoKitMeta({'movie_idx': 'm604', 'movie_name': 'white angel', 'release_year': '1994', 'rating': '4.40', 'votes': '99', 'genre': "['drama', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L650318
# Metadata: ConvoKitMeta({'movie_idx': 'm604', 'movie_name': 'white angel', 'release_year': '1994', 'rating': '4.40', 'votes': '99', 'genre': "['drama', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L650313
# Metadata: ConvoKitMeta({'movie_idx': 'm604', 'movie_name': 'white angel', 'release_year': '1994', 'rating': '4.40', 'votes': '99', 'genre': "['drama', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L650307
# Metadata: ConvoKitMeta({'movie_idx': 'm604', 'movie_name': 'white angel', 'release_year': '1994', 'rating': '4.40', 'votes': '99', 'genre': "['drama', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L650295
# Metadata: ConvoKitMeta({'movie_idx': 'm604', 'movie_name': 'white angel', 'release_year': '1994', 'rating': '4.40', 'votes': '99', 'genre': "['drama', 'thriller']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L650681
# Metadata: ConvoKitMeta({'movie_idx': 'm604', 'movie_name': 'white angel', 'release_year': '1994', 'rating': '4.40', 'votes': '99', 'genre': "['drama', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L650676
# Metadata: ConvoKitMeta({'movie_idx': 'm604', 'movie_name': 'white angel', 'release_year': '1994', 'rating': '4.40', 'votes': '99', 'genre': "['drama', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L650594
# Metadata: ConvoKitMeta({'movie_idx': 'm604', 'movie_name': 'white angel', 'release_year': '1994', 'rating': '4.40', 'votes': '99', 'genre': "['drama', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L650587
# Metadata: ConvoKitMeta({'movie_idx': 'm604', 'movie_name': 'white angel', 'release_year': '1994', 'rating': '4.40', 'votes': '99', 'genre': "['drama', 'thriller']"})
# Number of utterances in conversation: 6
#
# Conversation ID: L650580
# Metadata: ConvoKitMeta({'movie_idx': 'm604', 'movie_name': 'white angel', 'release_year': '1994', 'rating': '4.40', 'votes': '99', 'genre': "['drama', 'thriller']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L652758
# Metadata: ConvoKitMeta({'movie_idx': 'm605', 'movie_name': "who's your daddy?", 'release_year': '2003/I', 'rating': '4.50', 'votes': '2267', 'genre': "['comedy']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L652692
# Metadata: ConvoKitMeta({'movie_idx': 'm605', 'movie_name': "who's your daddy?", 'release_year': '2003/I', 'rating': '4.50', 'votes': '2267', 'genre': "['comedy']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L652543
# Metadata: ConvoKitMeta({'movie_idx': 'm605', 'movie_name': "who's your daddy?", 'release_year': '2003/I', 'rating': '4.50', 'votes': '2267', 'genre': "['comedy']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L652490
# Metadata: ConvoKitMeta({'movie_idx': 'm605', 'movie_name': "who's your daddy?", 'release_year': '2003/I', 'rating': '4.50', 'votes': '2267', 'genre': "['comedy']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L652486
# Metadata: ConvoKitMeta({'movie_idx': 'm605', 'movie_name': "who's your daddy?", 'release_year': '2003/I', 'rating': '4.50', 'votes': '2267', 'genre': "['comedy']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L652422
# Metadata: ConvoKitMeta({'movie_idx': 'm605', 'movie_name': "who's your daddy?", 'release_year': '2003/I', 'rating': '4.50', 'votes': '2267', 'genre': "['comedy']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L652414
# Metadata: ConvoKitMeta({'movie_idx': 'm605', 'movie_name': "who's your daddy?", 'release_year': '2003/I', 'rating': '4.50', 'votes': '2267', 'genre': "['comedy']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L652132
# Metadata: ConvoKitMeta({'movie_idx': 'm605', 'movie_name': "who's your daddy?", 'release_year': '2003/I', 'rating': '4.50', 'votes': '2267', 'genre': "['comedy']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L652124
# Metadata: ConvoKitMeta({'movie_idx': 'm605', 'movie_name': "who's your daddy?", 'release_year': '2003/I', 'rating': '4.50', 'votes': '2267', 'genre': "['comedy']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L652121
# Metadata: ConvoKitMeta({'movie_idx': 'm605', 'movie_name': "who's your daddy?", 'release_year': '2003/I', 'rating': '4.50', 'votes': '2267', 'genre': "['comedy']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L652118
# Metadata: ConvoKitMeta({'movie_idx': 'm605', 'movie_name': "who's your daddy?", 'release_year': '2003/I', 'rating': '4.50', 'votes': '2267', 'genre': "['comedy']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L652113
# Metadata: ConvoKitMeta({'movie_idx': 'm605', 'movie_name': "who's your daddy?", 'release_year': '2003/I', 'rating': '4.50', 'votes': '2267', 'genre': "['comedy']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L652111
# Metadata: ConvoKitMeta({'movie_idx': 'm605', 'movie_name': "who's your daddy?", 'release_year': '2003/I', 'rating': '4.50', 'votes': '2267', 'genre': "['comedy']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L652108
# Metadata: ConvoKitMeta({'movie_idx': 'm605', 'movie_name': "who's your daddy?", 'release_year': '2003/I', 'rating': '4.50', 'votes': '2267', 'genre': "['comedy']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L652105
# Metadata: ConvoKitMeta({'movie_idx': 'm605', 'movie_name': "who's your daddy?", 'release_year': '2003/I', 'rating': '4.50', 'votes': '2267', 'genre': "['comedy']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L652091
# Metadata: ConvoKitMeta({'movie_idx': 'm605', 'movie_name': "who's your daddy?", 'release_year': '2003/I', 'rating': '4.50', 'votes': '2267', 'genre': "['comedy']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L652089
# Metadata: ConvoKitMeta({'movie_idx': 'm605', 'movie_name': "who's your daddy?", 'release_year': '2003/I', 'rating': '4.50', 'votes': '2267', 'genre': "['comedy']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L652079
# Metadata: ConvoKitMeta({'movie_idx': 'm605', 'movie_name': "who's your daddy?", 'release_year': '2003/I', 'rating': '4.50', 'votes': '2267', 'genre': "['comedy']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L652075
# Metadata: ConvoKitMeta({'movie_idx': 'm605', 'movie_name': "who's your daddy?", 'release_year': '2003/I', 'rating': '4.50', 'votes': '2267', 'genre': "['comedy']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L652050
# Metadata: ConvoKitMeta({'movie_idx': 'm605', 'movie_name': "who's your daddy?", 'release_year': '2003/I', 'rating': '4.50', 'votes': '2267', 'genre': "['comedy']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L652017
# Metadata: ConvoKitMeta({'movie_idx': 'm605', 'movie_name': "who's your daddy?", 'release_year': '2003/I', 'rating': '4.50', 'votes': '2267', 'genre': "['comedy']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L652013
# Metadata: ConvoKitMeta({'movie_idx': 'm605', 'movie_name': "who's your daddy?", 'release_year': '2003/I', 'rating': '4.50', 'votes': '2267', 'genre': "['comedy']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L652010
# Metadata: ConvoKitMeta({'movie_idx': 'm605', 'movie_name': "who's your daddy?", 'release_year': '2003/I', 'rating': '4.50', 'votes': '2267', 'genre': "['comedy']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L652008
# Metadata: ConvoKitMeta({'movie_idx': 'm605', 'movie_name': "who's your daddy?", 'release_year': '2003/I', 'rating': '4.50', 'votes': '2267', 'genre': "['comedy']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L652004
# Metadata: ConvoKitMeta({'movie_idx': 'm605', 'movie_name': "who's your daddy?", 'release_year': '2003/I', 'rating': '4.50', 'votes': '2267', 'genre': "['comedy']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L651995
# Metadata: ConvoKitMeta({'movie_idx': 'm605', 'movie_name': "who's your daddy?", 'release_year': '2003/I', 'rating': '4.50', 'votes': '2267', 'genre': "['comedy']"})
# Number of utterances in conversation: 7
#
# Conversation ID: L651888
# Metadata: ConvoKitMeta({'movie_idx': 'm605', 'movie_name': "who's your daddy?", 'release_year': '2003/I', 'rating': '4.50', 'votes': '2267', 'genre': "['comedy']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L651885
# Metadata: ConvoKitMeta({'movie_idx': 'm605', 'movie_name': "who's your daddy?", 'release_year': '2003/I', 'rating': '4.50', 'votes': '2267', 'genre': "['comedy']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L651883
# Metadata: ConvoKitMeta({'movie_idx': 'm605', 'movie_name': "who's your daddy?", 'release_year': '2003/I', 'rating': '4.50', 'votes': '2267', 'genre': "['comedy']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L651880
# Metadata: ConvoKitMeta({'movie_idx': 'm605', 'movie_name': "who's your daddy?", 'release_year': '2003/I', 'rating': '4.50', 'votes': '2267', 'genre': "['comedy']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L651878
# Metadata: ConvoKitMeta({'movie_idx': 'm605', 'movie_name': "who's your daddy?", 'release_year': '2003/I', 'rating': '4.50', 'votes': '2267', 'genre': "['comedy']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L651876
# Metadata: ConvoKitMeta({'movie_idx': 'm605', 'movie_name': "who's your daddy?", 'release_year': '2003/I', 'rating': '4.50', 'votes': '2267', 'genre': "['comedy']"})
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
# Create empty lists to store data
conversation_ids = []
movie_indices = []
movie_names = []
release_years = []
ratings = []
votes = []
genres = []
num_utterances = []

# Loop through conversations and extract data
for convo_id in corpus.get_conversation_ids():
    convo = corpus.get_conversation(convo_id)

    # Extract metadata from ConvoKitMeta object
    metadata = convo.meta

    # Append data to respective lists
    conversation_ids.append(convo_id)
    movie_indices.append(metadata['movie_idx'])
    movie_names.append(metadata['movie_name'])
    release_years.append(metadata['release_year'])
    ratings.append(metadata['rating'])
    votes.append(metadata['votes'])
    genres.append(metadata['genre'])
    num_utterances.append(len(convo.get_utterance_ids()))

# Create a DataFrame from the lists
data = {
    'Conversation ID': conversation_ids,
    'Movie Index': movie_indices,
    'Movie Name': movie_names,
    'Rating': ratings,
}

df = pd.DataFrame(data)

# %%
df
# Out:
#       Conversation ID Movie Index                  Movie Name Rating
# 0               L1044          m0  10 things i hate about you   6.90
# 1                L984          m0  10 things i hate about you   6.90
# 2                L924          m0  10 things i hate about you   6.90
# 3                L870          m0  10 things i hate about you   6.90
# 4                L866          m0  10 things i hate about you   6.90
# ...               ...         ...                         ...    ...
# 83092         L666324        m616                   zulu dawn   6.40
# 83093         L666262        m616                   zulu dawn   6.40
# 83094         L666520        m616                   zulu dawn   6.40
# 83095         L666369        m616                   zulu dawn   6.40
# 83096         L666256        m616                   zulu dawn   6.40
#
# [83097 rows x 4 columns]

# %%
# Create a Reader object specifying the rating scale
reader = Reader(rating_scale=(1, 10))

# %%
# Load the dataset into Surprise format
data = df[['Conversation ID','Movie Name','Rating']]
data = Dataset.load_from_df(data, reader)

# Split the data into training and testing sets (80% train, 20% test)
trainset, testset = train_test_split(data, test_size=0.2, random_state=42)

# Create and train the SVD recommendation model
model = SVD()
model.fit(trainset)

# Evaluate the model on the testing data (calculate RMSE)
predictions = model.test(testset)
rmse = accuracy.rmse(predictions)
# Out:
# RMSE: 0.0644

# %%
# Generate recommendations for a specific user (e.g., user_id='L236416')
user_id = 'L36547'
user_movies = df[df['Conversation ID'] == user_id]['Movie Name'].unique()

# Create a list of unrated movies for the user
all_movies = df['Movie Name'].unique()
unrated_movies = np.setdiff1d(all_movies, user_movies)

# Generate predictions for unrated movies
user_recommendations = []
for movie_id in unrated_movies:
    predicted_rating = model.predict(user_id, movie_id).est
    user_recommendations.append((movie_id, predicted_rating))

    # Sort recommendations by predicted rating (highest first)
user_recommendations.sort(key=lambda x: x[1], reverse=True)

# %%
# Display the top n recommendations
top_n = 3
print(f'Top {top_n} recommendations for user {user_id}:')
for movie_id, predicted_rating in user_recommendations[:top_n]:
    print(f'Movie ID: {movie_id}, Predicted Rating: {predicted_rating:.2f}')
# Out:
# Top 3 recommendations for user L36547:
# Movie ID: neuromancer, Predicted Rating: 9.17
# Movie ID: the godfather, Predicted Rating: 9.05
# Movie ID: casablanca, Predicted Rating: 8.81
